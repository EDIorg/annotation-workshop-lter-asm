# %% [markdown]
# # Fetchs Data Packages, Keywords and Thesaurus info
# This Notebook uses web services to download the packageid,title and list of keywords for each LTER dataset in EDI (based on the knb-lter-* scope) and queries the LTER Thesaurus using Tematres web services to gather information on which keywords are found in the thesaurus, and if so, which high-level category it falls into. Several intermediate CSV files are created along the way and contain the information needed to produce a spreadsheet listing the keywording data using a separate R program.  -John Porter, 2022

# %% [markdown]
# ### Fetch keyword data from PASTA

# %%
import requests

r=requests.get('https://pasta.lternet.edu/package/search/eml?defType=edismax&q=*&fq=-scope:ecotrends&fq=-scope:lter-landsat*&fq=scope:knb-lter-*&fl=packageid,title,keyword&sort=score,desc&sort=packageid,asc&debug=false&rows=1000000',verify=False)
f=open("resultSetAll.xml","w",encoding='utf-8')
f.write(r.text)
f.close()
print("Done")
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pasta.lternet.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Done

# %% [markdown]
# ### Parse ResultSet XML and create a csv file to read in as a Pandas data frame

# %%
import xml.etree.ElementTree as Xet
import numpy as np
import pandas as pd 

# create an output file and write the header
f=open("resultSetKeywords.csv","w",encoding="utf=8")
f.write("packageid,title,keyword\n")
# now parse the XML and write it out
resultSetxmlparse=Xet.parse("resultSetAll.xml")
root=resultSetxmlparse.getroot()

for i in root:
    packageid=i.find("packageid").text
    title=i.find("title").text
    title=title.replace('\r','').replace('\n','') # get rid of embedded linefeeds in titles
    for k in i.iter("keyword"):
        keyword=str(k.text)
        f.write(packageid+',"'+title+'","'+keyword+'"\n')
f.close()  
resultSetDataFrame =pd.read_csv("resultSetKeywords.csv" 
          ,skiprows=1
            ,sep=","  
                ,quotechar='"' 
           , names=[
                    "pakcageid",     
                    "title",     
                    "keyword"]
                               )
print(resultSetDataFrame.info())
print("Done")
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110843 entries, 0 to 110842
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   pakcageid  110843 non-null  object
#  1   title      110843 non-null  object
#  2   keyword    110842 non-null  object
# dtypes: object(3)
# memory usage: 2.5+ MB
# None
# Done

# %% [markdown]
# ### Get list of top-level LTER Vocab units

# %%
topr=requests.get('https://vocab.lternet.edu/vocab/vocab/services.php?task=fetchTopTerms',verify=False)
f=open("TopLevelTerms.xml","w",encoding='utf-8')
f.write(topr.text)
f.close()
print("Done")
# Out:
# Done

# %% [markdown]
# ### and create  lists of their names and term_ids

# %%
topTermsxmlparse=Xet.parse("TopLevelTerms.xml")
rootTop=topTermsxmlparse.getroot()
topCounter=0

term_id=list()
term_string=list()
for i in rootTop.iter('term_id'):
    term_id.append(i.text)
for i in rootTop.iter('string'):
    term_string.append(i.text)
    topCounter=topCounter+1
print(term_id)
print(term_string)

f=open("TopLevelTerms.csv","w",encoding="utf-8")
for i in range(len(term_id)):
    f.write(term_string[i]+","+str(term_id[i])+"\n")
f.close()
# Out:
# ['799', '651', '698', '667', '693', '655', '643', '694', '173', '395']
# ['organizational units', 'disciplines', 'events', 'measurements', 'methods', 'processes', 'substances', 'substrates', 'ecosystems', 'organisms']

# %% [markdown]
# ### Run Queries of keywords against Tematres web services to see if they match and what the top of the hierarchy is

# %%
import warnings

# create a list of keywords without duplicates
kwList=[]
[kwList.append(x) for x in resultSetDataFrame.keyword if x not in kwList]
print(len(kwList))
print(kwList)
# Out:
# 8598
# ['history', 'Adaptive Management Areas (AMA)', 'Cascade Center for Ecosystem Management (CCEM)', 'Long-Term Ecological Research (LTER)', 'International Biological Program (IBP)', 'Research Natural Areas (RNA)', 'information management', 'air temperature', 'maximum temperature', 'historical value', 'forest ecosystems', 'H. J. Andrews Experimental Forest (AND)', 'attitudes and perceptions', 'public participation', 'experimental forests', 'Arthropods', 'Forest ecosystems', 'Insects', 'Invertebrates', 'Old-growth forests', 'Populations', 'Vascular plants', 'Birds', 'Vertebrates', 'Amphibians', 'Reptiles', 'Mosses', 'Mammals', 'Bryophytes', 'Environmental gradients', 'Fungi', 'Conservation biology', 'Ecology', 'Forest management', 'Lichens', 'Phenology', 'stand structure', 'forest dynamics', 'measurements', 'productivity', 'biomass', 'plant properties', 'wind', 'community composition', 'plant species composition', 'spatial properties', 'long term', 'permanent plots', 'succession', 'primary production', 'plant growth', 'mortality', 'regeneration', 'disease', 'disturbance', 'woody debris', 'organic matter', 'ecosystems', 'forests', 'old growth forests', 'trees', 'windthrow', 'Decomposition', 'Detritus', 'Organic matter', 'Respiration', 'Primary production', 'soil properties', 'topography', 'inorganic nutrients', 'Inventory', 'Reference stands', 'Woody debris', 'soil respiration', 'respiration', 'soil', 'Coarse woody debris - terrestrial', 'Moisture stress', 'N-fixation', 'Nitrogen', 'Inorganic nutrients', 'Disturbance', 'Soil chemistry', 'Soil organic matter', 'Soil respiration', 'Dendrochronology', 'Mensuration', 'Silviculture', 'Tree measurements', 'community dynamics', 'trophic structure', 'species interactions', 'competition', 'burning', 'timber harvest', 'clearcutting', 'Animal-habitat modeling', 'debris flows', 'landslides', 'erosion', 'sedimentation', 'sediments', 'water temperature', 'Carbon', 'Microclimate', 'Carbon cycling', 'Soil moisture', 'Soil temperature', 'Air temperature', 'Microbiota', 'Fire', 'Fire history', 'community patterns', 'populations', 'streams', 'liverworts', 'mosses', 'bryophytes', 'vegetation', 'environmental gradients', 'riparian ecosystems', 'Age structure', 'Climate/Meteorology', 'Ecosystem processes', 'Channel geomorphology', 'Geomorphology', 'Riparian ecosystems', 'Riparian vegetation', 'Clearcutting', 'Evapotranspiration', 'Gravimetric sampling', 'Interception', 'Vegetation', 'Water balance', 'Groundwater processes', 'Hydrologic processes', 'Hyporheic zone', 'Step pools', 'Stream order', 'Subsurface flow', 'communities', 'community structure', 'plant ecology', 'canopies', 'understory vegetation', 'canopy cover', 'nutrients', 'plants', 'hydrology', 'meteorology', 'climatology', 'climate change', 'atmospheric pressure', 'vapor pressure', 'relative humidity', 'precipitation', 'snow accumulation', 'wind direction', 'wind speed', 'snow', 'soil temperature', 'photosynthetically active radiation', 'solar radiation', 'soil moisture', 'monitoring', 'History', 'Mapping', 'Road management', 'Roads', 'Topography', 'Digital Elevation Model (DEM)', 'Administration', 'Experimental Forests', 'GIS', 'Watershed', 'Timber harvesting', 'Salvage logging', 'Hydrology data', 'Hydrology/Water', 'Streamflow', 'Experimental watershed studies', 'Stream functions', 'Hydrologic modeling', 'Hydrology - vegetation model', 'seed production', 'reproduction', 'cones', 'Hemispherical photography', 'dew point', 'microclimate', 'water content', 'temperature', 'reference stands', 'growth', 'environmental indexes', 'moisture stress', 'Disturbance history', 'Geology/geomorphology', 'Minerology', 'Soil classification', 'Soils', 'Remote sensing', 'Vegetation modeling', 'Vegetation types', 'Climate data', 'Climate modeling', 'Meteorological measurements', 'Precipitation', 'Precipitation modeling', 'Landslides/earthflows', 'Slope stability', 'Hazard assessment', 'Debris slides/flows', 'Movement monitoring', 'Plant associations', 'Clearcuts' ...

# %%
f=open("termHierarchies.csv","w",encoding='utf-8',buffering=1)
counter=0
startCounter=0  # use for restarts. Be sure to rename old file before it is overwritten
for kw in kwList:
    #print(kw)
    counter=counter+1
    if (counter >= startCounter):
        warnings.filterwarnings("ignore") # eliminate security warning about verify option
        termr=requests.get('https://vocab.lternet.edu/vocab/vocab/services.php?task=search&arg='+str(kw),verify=False)
        warnings.filterwarnings("default")
        kwRoot=Xet.fromstring(termr.text)
        for i in kwRoot.iter("term"):
            if (i.find("string") is not None):
                termString=str(i.find("string").text )
                indexString=str(i.find("index").text )
                if (kw.lower() == termString.lower()):
                    print(str(counter)+',"'+termString+'",'+indexString)
                    f.write('"'+ kw +'",'+indexString+'\n')
f.close()
print("done")
# Out:
# 1,"history",|651|248
# 8,"air temperature",|667|668|579|22
# 9,"maximum temperature",|667|668|579|329
# 10,"historical value",|651|248|247
# 11,"forest ecosystems",|173|798|212
# 16,"arthropods",|395|33|271|45
# 17,"forest ecosystems",|173|798|212
# 18,"insects",|395|33|271|45|267
# 19,"invertebrates",|395|33|271
# 21,"populations",|799|439
# 22,"vascular plants",|395|433|951
# 23,"birds",|395|33|614|69
# 24,"vertebrates",|395|33|614
# 25,"amphibians",|395|33|614|32
# 26,"reptiles",|395|33|614|466
# 27,"mosses",|395|433|354
# 28,"mammals",|395|33|614|320
# 29,"bryophytes",|395|433|354|75
# 31,"fungi",|395|218
# 33,"ecology",|651|172
# 35,"lichens",|395|297
# 36,"phenology",|651|67|413
# 37,"stand structure",|799|114|119|991
# 38,"forest dynamics",|651|172|427|931
# 39,"measurements",None
# 40,"productivity",|667|716|450
# 41,"biomass",|667|716|68
# 42,"plant properties",|667|917
# 43,"wind",|667|692|633
# 44,"community composition",|667|674|115
# 45,"plant species composition",|651|64|432
# 46,"spatial properties",|667|673
# 47,"long term",|667|670|311
# 48,"permanent plots",|693|801|409
# 49,"succession",|655|656|686
# 50,"primary production",|655|656|449|447
# 51,"plant growth",|655|656|449|428
# 52,"mortality",|655|656|298|353
# 53,"regeneration",|655|656|298|461
# 54,"disease",|655|656|155
# 55,"disturbance",|655|662
# 56,"woody debris",|643|665|638
# 57,"organic matter",|643|393
# 58,"ecosystems",|173
# 59,"forests",|173|798|212|2
# 60,"old growth forests",|173|798|212|2|388
# 61,"trees",|395|433|951|1
# 63,"decomposition",|655|658|137
# 64,"detritus",|643|665|148
# 65,"organic matter",|643|393
# 66,"respiration",|655|656|88|467
# 67,"primary production",|655|656|449|447
# 68,"soil properties",|667|714
# 69,"topography",|667|673|589
# 70,"inorganic nutrients",|643|665|266
# 72,"reference stands",|693|801|984
# 73,"woody debris",|643|665|638
# 74,"soil respiration",|667|714|528
# 75,"respiration",|655|656|88|467
# 76,"soil",|694|535
# 80,"nitrogen",|643|666|372
# 81,"inorganic nutrients",|643|665|266
# 82,"disturbance",|655|662
# 83,"soil chemistry",|651|99|521
# 84,"soil organic matter",|643|393|527
# 85,"soil respiration",|667|714|528
# 86,"dendrochronology",|651|67|140
# 88,"silviculture",|651|17|506
# 90,"community dynamics",|651|172|116
# 91,"trophic structure",|667|674|603
# 92,"species interactions",|655|656|544
# 93,"competition",|655|656|544|120
# 94,"burning",|655|657|79
# 95,"timber harvest",|655|239|587
# 96,"clearcutting",|655|239|587|108
# 98,"debris flows",|698|805|945|948
# 99,"landslides",|698|805|945|946
# 100,"erosion",|655|657|660|181
# 101,"sedimentation",|655|657|660|492
# 102,"sediments",|643|493
# 103,"water temperature",|667|668|579|625
# 104,"carbon",|643|666|86
# 105,"microclimate",|667|692|109|340
# 106,"carbon cycling",|655|656|88
# 107,"soil moisture",|643|617|525
# 108,"soil temperature",|667|668|579|530
# 109,"air temperature",|667|668|579|22
# 113,"community patterns",|799|114|117
# 114,"populations",|799|439
# 115,"streams",|173|41|562
# 116,"liverworts",|395|433|306
# 117,"mosses",|395|433|354
# 118,"bryophytes",|395|433|354|75
# 119,"vegetation",|395|433|612
# 126,"geomorphology",|651|652|225
# 129,"clearcutting",|655|239|587|108
# 130,"evapotranspiration",|655|657|661|185
# 132,"interception",|667|672|443|268
# 133,"vegetation",|395|433|612
# 134,"water balance",|667|618
# 136,"hydrologic processes",|655|657|661
# 137,"hyporheic zone",|694|261
# 139,"stream order",|667|672|560
# 141,"communities",|799|114
# 142,"community structure",|799|114|119
# 143,"plant ecology",|651|172|427
# 144,"canopies",|694|82
# 145,"understory vegetation",|395|433|612|607
# 146,"canopy cover",|667|716|83
# 147,"nutrients",|643|665|384
# 148,"plants",|395|433
# 149,"hydrology",|651|259
# 150,"meteorology",|651|333
# 151,"climatology",|651|333|111
# 152,"climate change",|651|333|111|110
# 153,"atmospheric pressure",|667|692|50
# 154,"vapor pressure",|667|692|611
# 155,"relative humidity",|667|692|611|253|463
# 156,"precipitation",|667|672|443
# 157,"snow accumulation",|667|672|443|514
# 158,"wind direction",|667|692|633|634
# 159,"wind speed",|667|692|633|635
# 160,"snow",|694|513
# 161,"soil temperature",|667|668|579|530
# 162,"photosynthetically active radiation",|667|668|454|418
# 163,"solar radiation",|667|668|454|536
# 164,"soil moisture",|643|617|525
# 165,"monitoring",|655|664|349
# 166,"history",|651|248
# 167,"mapping",|655|664|323
# 169,"roads",|694|475
# 170,"topography",|667|673|589
# 180,"streamflow",|655|657|661|561
# 185,"seed production",|655|656|449|986
# 186,"reproduction",|655|656|298|465
# 187,"cones",|395|433|914
# 189,"dew point",|667|692|150
# 190,"microclimate",|667|692|109|340
# 191,"water content",|667|672|621
# 192,"temperature",|667|668|579
# 193,"reference stands",|693|801|984
# 194,"growth",|655|656|298|236
# 202,"remote sensing",|655|664|464
# 208,"precipitation",|667|672|443
# 216,"clearcuts",|173|798|212|2|107
# 220,"stream order",|667|672|560
# 221,"water chemistry",|651|99|619
# 222,"suspended solids",|667|691|623|574
# 223,"discharge",|655|657|661|154
# 224,"streamflow",|655|657|661|561
# 225,"dissolved nutrients",|643|665|384|159
# 226,"water",|643|617
# 227,"chemical properties",|667|671
# 228,"concentration",|667|671|913
# 229,"fire management",|655|928|929
# 230,"restoration",|655|469
# 231,"meadows",|173|798|232|330
# 232,"habitats",|799|238
# 233,"demography",|651|682
# 234,"ecology",|651|172
# 235,"stream ecology",|651|172|559
# 236,"population dynamics",|651|172|438
# 237,"floods",|698|805|198
# 238,"aquatic ecosystems",|173|41
# 239,"animals",|395|33
# 240,"vertebrates",|395|33|614
# 241,"amphibians",|395|33|614|32
# 242,"fishes",|395|33|614|196
# 243,"trout",|395|33|614|196|604
# 244,"reptiles",|395|33|614|466
# 246,"aquatic ecosystems",|173|41
# 247,"nitrogen cycling",|655|658|383|375
# 248,"storms",|698|805|556
# 249,"stream ecology",|651|172|559
# 250,"water chemistry",|651|99|619
# 255,"biomass",|667|716|68
# 257,"floods",|698|805|198
# 258,"wind",|667|692|633
# 261,"nutrients",|643|665|384
# 262,"litterfall",|655|656|305
# 263,"phosphorus",|643|666|416
# 264,"roots",|395|433|477
# 265,"wood",|643|665|637
# 268,"fire management",|655|928|929
# 269,"forest floor",|694|213
# 271,"decay rates",|667|136
# 272,"decomposition",|655|658|137
# 273,"nutrient cycling",|655|658|383
# 274,"coarse woody debris",|643|665|638|112
# 275,"invertebrates",|395|33|271
# 276,"logs",|395|433|951|1|310
# 279,"thinning",|655|239|584
# 280,"detritus",|643|665|148
# 281,"wood",|643|665|637
# 283,"geomorphology",|651|652|225
# 284,"silviculture",|651|17|506
# 285,"hydrologic processes",|655|657|661
# 286,"stream discharge",|655|657|661|154|558
# 287,"long term monitoring",|655|664|349|313
# 288,"runoff",|643|617|479
# 289,"watersheds",|173|798|626
# 292,"species richness",|651|64|546
# 293,"aquatic invertebrates",|395|33|271|42
# 294,"arthropods",|395|33|271|45
# 295,"insects",|395|33|271|45|267
# 296,"macroinvertebrates",|395|33|271|318
# 297,"aquatic invertebrates",|395|33|271|42
# 298,"species lists",|799|541|545
# 300,"forest ecology",|651|172|211
# 301,"successional dynamics",|651|172|566
# 302,"biodiversity",|651|64
# 303,"species diversity",|651|64|543
# 304,"tree growth",|655|656|298|236|597
# 305,"tree mortality",|655|656|298|353|598
# 306,"forest disturbance",|655|662|210
# 307,"vascular plants",|395|433|951
# 308,"herbs",|395|433|951|245
# 309,"shrubs",|395|433|951|503
# 310,"climate change",|651|333|111|110
# 313,"tracers",|693|801|593
# 314,"dissolved oxygen",|643|666|397|161
# 315,"isotopes",|643|276
# 320,"productivity",|667|716|450
# 327,"bark",|395|433|54
# 328,"calcium",|643|666|81
# 330,"foliage",|395|433|206
# 331,"forbs",|395|433|951|245|209
# 332,"nutrient budgets",|667|716|382|1001
# 334,"shrubs",|395|433|951|503
# 336,"trees",|395|433|951|1
# 338,"phenology",|651|67|413
# 339,"birds",|395|33|614|69
# 340,"spatial variability",|667|673|539
# 348,"biogeochemistry",|651|65
# 351,"water temperature",|667|668|579|625
# 354,"plant cover",|667|716|426
# 355,"diversity",|667|674|166
# 356,"resource management",|655|928
# 357,"survival",|655|656|298|572
# 358,"thinning",|655|239|584
# 359,"terrestrial ecosystems",|173|798
# 360,"seedlings",|395|433|498
# 361,"canopy gaps",|395|433|612|84
# 368,"evaporation",|655|657|661|185|184
# 369,"throughfall",|667|672|443|585
# 370,"plant species",|799|541|431
# 373,"LiDAR",|693|705|263|807|953
# 391,"land cover",|667|673|279
# 395,"resource management",|655|928
# 397,"land use history",|651|248|281
# 398,"trophic dynamics",|651|172|602
# 399,"light",|667|668|454|299
# 400,"algae",|395|23
# 401,"salamanders",|395|33|614|32|480
# 402,"electrical conductivity",|667|668|176
# 403,"specific conductivity",|667|668|176|122|548
# 404,"surveys",|693|571
# 410,"conservation",|651|124
# 411,"accumulation",|655|8
# 413,"species abundance",|667|674|6|990
# 414,"metabolism",|655|800|332
# 415,"recruitment",|698|710|458
# 416,"census",|693|571|96
# 417,"soil water content",|667|672|621|534
# 418,"time domain reflectometry",|693|801|588
# 419,"droughts",|698|805|168
# 420,"stable isotopes",|643|276|551
# 422,"genetics",|651|67|223
# 424,"leaf area",|667|917|288
# 425,"tundra",|173|798|605
# 426,"fertilization",|655|191
# 427,"foliar nitrogen",|667|671|374|930
# 428,"carbon to nitrogen ratio",|667|671|92
# 429,"specific leaf area",|667|917|288|549
# 430,"leaves",|395|433|293
# 431,"species lists",|799|541|545
# 432,"relative abundance",|667|674|6|462
# 433,"weather",|667|692|627
# 434,"radiation",|667|668|454
# 436,"herbivory",|655|656|544|244
# 437,"fertilizer",|643|192
# 438,"rain",|667|672|443|455
# 443,"nitrogen",|643|666|372
# 444,"carbon",|643|666|86
# 448,"plant biomass",|667|716|68|423
# 449,"bacteria",|395|336|51
# 450,"bacterial production",|655|656|449|53
# 451,"carbon assimilation",|655|656|88|87
# 452,"lakes",|173|41|278
# 453,"water level",|667|672|622
# 454,"stage height",|667|672|622|553
# 455,"net ecosystem exchange",|667|716|883
# 456,"heat flux",|667|205|241
# 457,"eddy covariance",|655|657|659|174
# 457,"eddy covariance",None
# 459,"burns",|698|805|906
# 460,"climate",|667|692|109
# 461,"humidity",|667|692|611|253
# 465,"phosphorus",|643|666|416
# 466,"ammonium",|643|666|372|373|31
# 467,"total dissolved nitrogen",|667|671|374|590|999
# 468,"alkalinity",|667|671|24
# 469,"dissolved organic carbon",|643|666|86|160
# 470,"dissolved inorganic carbon",|643|666|86|158
# 471,"particulates",|643|891
# 472,"particulate organic carbon",|643|666|86|390|892
# 473,"cations",|643|272|93
# 474,"anions",|643|272|34
# 475,"sulfate",|643|666|569|567
# 476,"chemistry",|651|99
# 477,"conductivity",|667|668|176|122
# 479,"freshwater",|694|216
# 480,"limnology",|651|301
# 482,"fungi",|395|218
# 483,"nitrogen-15",|643|666|372|379
# 484,"leaf litter",|395|433|612|291
# 485,"snowfences",|693|801|517
# 486,"ecosystem respiration",|667|716|924
# 487,"snow depth",|667|668|145|515
# 488,"flux",None
# 489,"fires",|698|805|195
# 490,"recovery",|655|457
# 491,"reflectance",|667|668|460
# 494,"thaw depth",|667|668|145|582
# 495,"permafrost",|694|408
# 496,"elevation",|667|673|879|177
# 497,"aspect",|667|673|879|878
# 498,"carbon cycling",|655|656|88
# 499,"bulk density",|667|668|77
# 500,"depth",|667|668|145
# 501,"organic layer",|694|535|392
# 502,"nutrient cycles",|667|716|382
# 503,"photosynthesis",|655|800|417
# 504,"irradiance",|667|668|274
# 505,"dataloggers",|693|801|135
# 511,"ph",|667|671|410
# 519,"longitude",|667|673|308|884|886
# 520,"latitude",|667|673|308|884|885
# 521,"global positioning systems",|693|705|228
# 522,"primary productivity",None
# 523,"leaf area index",|667|917|288|289
# 524,"percent nitrogen",|667|671|405
# 525,"percent carbon",|667|671|403
# 527,"chlorophyll",|643|665|102
# 537,"dissolved organic nitrogen",|643|666|372|394|888
# 538,"nitrate",|643|666|372|373|368
# 539,"soil chemistry",|651|99|521
# 540,"soil water",|643|617|533
# 541,"soil nitrogen",|643|666|372|896
# 542,"soil carbon",|643|666|86|520
# 543,"production",|655|656|449
# 547,"phytoplankton",|395|802|421
# 549,"chlorophyll a",|643|665|103
# 558,"microbial biomass",|667|716|68|339
# 559,"zooplankton",|395|802|641
# 560,"ponds",|173|41|975
# 561,"ph",|667|671|410
# 562,"methane",|643|666|86|334
# 563,"carbon dioxide",|643|666|86|89
# 564,"gases",|643|221
# 569,"calcium",|643|666|81
# 570,"magnesium",|643|666|319
# 571,"potassium",|643|666|442
# 572,"sodium",|643|666|518
# 573,"soluble reactive phosphorus",|643|666|416|537
# 574,"silica",|643|666|505|504
# 575,"chloride",|643|666|101|100
# 581,"lichens",|395|297
# 582,"soil organic matter",|643|393|527
# 583,"percent organic carbon",|667|671|403|406
# 584,"organic carbon",|643|666|86|390
# 585,"nematodes",|395|33|271|362
# 586,"protozoa",|395|336|452
# 587,"gas flux",|667|205|220
# 588,"microbial activity",|655|656|338
# 589,"phosphate",|643|666|416|415
# 590,"gross primary production",|655|656|449|447|905
# 595,"biogeochemistry",|651|65
# 596,"total organic carbon",|667|671|591
# 597,"nitrite",|643|666|372|373|371
# 598,"phaeophytin",|643|665|412|411
# 599,"benthos",|395|882
# 600,"ammonia",|643|666|372|373|30
# 601,"substrates",None
# 602,"groundwater",|694|235
# 603,"nitrification",|655|658|383|375|370
# 604,"mineralization",|655|658|341
# 605,"thermokarst",|173|798|994
# 608,"gastropods",|395|33|271|348|222
# 609,"pitfall traps",|693|801|422
# 619,"water table",|694|235|624
# 623,"rotifers",|395|336|452|478
# 624,"soil texture",|667|714|531
# 625,"photo point imagery",|693|705|263|950
# 626,"litter decomposition",|655|658|137|303
# 641,"soil horizons",|694|535|523
# 643,"nitrogen mineralization",|655|658|383|375|378
# 644,"soil nutrients",|643|665|384|526
# 657,"wildfires",|698|805|195|632
# 659,"models",|693|808|345
# 661,"mark and recapture",|693|801|980
# 668,"flowers",|395|433|200
# 670,"rivers",|173|41|474
# 671,"small mammals",|395|33|614|320|511
# 672,"leaf nutrients",|643|665|384|292
# 673,"litter",|643|665|302
# 674,"translocation",None
# 675,"fine roots",|395|433|477|193
# 676,"litterbags",|693|801|304
# 677,"flowering",|698|710|199
# 678,"herbivores",|799|208|125|243
# 679,"stems",|395|433|612|555
# 680,"plant phenology",|651|67|413|429
# 685,"soil warming",|655|657|660|532
# 698,"warming",|655|657|925
# 699,"predators",|799|208|445
# 702,"seasonality",|667|670|489
# 708,"genomics",|651|67|907
# 708,"genomics",|651|957
# 711,"fluorescence",|667|668|202
# 725,"disturbances",|698|805
# 734,"porosity",|667|668|441
# 735,"hydraulic conductance",|667|672|256
# 738,"iron",|643|666|273
# 739,"strontium",|643|666|563
# 740,"manganese",|643|666|321
# 741,"zinc",|643|666|640
# 742,"aluminum",|643|666|28
# 743,"silicon",|643|666|505
# 760,"modeling",|655|664|344
# 761,"nitrogen cycling",|655|658|383|375
# 762,"nitrogen limitation",|667|716|971
# 772,"carbon flux",|667|205|90
# 773,"plant communities",|799|114|424
# 791,"plant height",|667|917|1004
# 793,"shrews",|395|33|614|320|511|502
# 794,"trapping",|655|664|596
# 806,"seston",|395|500
# 824,"fauna",|395|33|189
# 841,"atmosphere",|694|18|48
# 842,"denitrification",|655|658|383|375|142
# 843,"microbial nitrogen",|643|666|372|964
# 844,"roots",|395|433|477
# 856,"invasive species",|799|541|269
# 862,"vegetation dynamics",|651|172|427|613
# 878,"urban",|667|673|609
# 882,"riparian",|667|673|473
# 892,"mapping",|655|664|323
# 951,"lysimeters",|693|801|315
# 952,"soil solution chemistry",|651|99|529
# 955,"soil",|694|535
# 956,"temperature",|667|668|579
# 957,"climate",|667|692|109
# 971,"geographic information systems",|651|653|224
# 977,"oxygen",|643|666|397
# 978,"irrigation",|655|657|661|275
# 991,"humans",|395|33|614|320|251
# 996,"plant ecology",|651|172|427
# 997,"infiltration",|655|657|661|265
# 998,"foliage",|395|433|206
# 999,"lead",|643|666|287
# 1000,"sulfur",|643|666|569
# 1008,"geography",|651|653
# 1012,"landscape change",|655|284
# 1014,"pollution",|643|436
# 1021,"geographic information systems",|651|653|224
# 1022,"aerial imagery",|693|705|263|807
# 1023,"landscape",None
# 1024,"spatial methods",|693|705
# 1025,"land use",|667|673|280
# 1028,"land cover",|667|673|279
# 1031,"disturbance patterns",|667|712|165
# 1037,"species",|799|541
# 1038,"nitrous oxide",|643|666|372|373|380
# 1042,"turbidity",|667|691|606
# 1043,"bicarbonate",|643|666|86|63
# 1063,"estuaries",|173|41|182
# 1064,"oceans",|173|41|695
# 1065,"water column",|694|620
# 1088,"seawater",|694|701
# 1097,"food webs",|799|208
# 1098,"phaeopigments",|643|665|412
# 1099,"diatoms",|395|23|151
# 1100,"oceanography",|651|700
# 1101,"porewater",|643|617|440
# 1142,"salinity",|667|671|481
# 1143,"soil bulk density",|667|714|519
# 1145,"water properties",|667|691
# 1147,"bathymetry",|667|673|59
# 1150,"ocean currents",|655|657|386
# 1151,"sea level",|667|672|622|944
# 1152,"temporal properties",|667|670
# 1154,"water balance",|667|618
# 1155,"physical processes",|655|657
# 1156,"wave height",|667|672|622|959
# 1157,"ice",|694|262
# 1159,"winter",|667|670|636
# 1161,"moorings",|693|801|351
# 1162,"air",|694|18
# 1166,"distribution",None
# 1174,"transects",|693|801|594
# 1180,"tree seedlings",|395|433|498|997
# 1188,"nitrogen fixation",|655|658|383|375|377
# 1189,"amino acids",|643|665|29
# 1192,"bogs",|173|630|70
# 1194,"deuterium",|643|617|149
# 1204,"shapefiles",None
# 1206,"maps",None
# 1213,"boundaries",|667|673|308|899
# 1215,"basins",|694|58
# 1219,"locations",|667|673|308
# 1229,"species composition",|667|674|166|542
# 1231,"density",|667|668|916
# 1233,"tree rings",|395|433|951|1|599
# 1234,"dendrochronology",|651|67|140
# 1241,"browsing",|655|239|74
# 1243,"clearcuts",|173|798|212|2|107
# 1245,"stand density",|667|668|916|992
# 1246,"basal area",|667|917|56
# 1251,"pressure",None
# 1252,"inorganic nitrogen",|643|666|372|922
# 1253,"hydrogen",|643|666|933
# 1256,"soil ph",|667|671|410|988
# 1269,"floodplain",|173|630|197
# 1271,"boreal forests",|173|798|212|2|72
# 1273,"evaporation",|655|657|661|185|184
# 1278,"charcoal",|643|665|98
# 1286,"ions",|643|272
# 1287,"neutron probe",|693|801|366
# 1288,"digital elevation model",|693|705|152
# 1296,"allometry",|667|716|25
# 1298,"mesic soils",|694|535|331
# 1299,"humic soils",|694|535|252
# 1303,"dissolved inorganic nitrogen",|643|666|372|922|923
# 1308,"seedling establishment",|698|710|497
# 1310,"bark",|395|433|54
# 1311,"beetles",|395|33|271|45|267|60
# 1313,"pheromones",|643|665|414
# 1318,"bud burst",|698|710|901
# 1324,"subsidence",|655|657|660|564
# 1331,"peatland",|173|630|402
# 1332,"wetlands",|173|630
# 1339,"soil phosphorus",|643|666|416|987
# 1341,"fire severity",|667|712|194
# 1345,"remote sensing",|655|664|464
# 1346,"aboveground production",|655|656|449|5
# 1347,"net primary production",|655|656|449|447|363
# 1353,"treeline",|395|433|612|600
# 1356,"seeds",|395|433|499
# 1361,"log decomposition",|655|658|137|963
# 1364,"microtopography",|667|673|589|965
# 1368,"net radiation",|667|668|454|365
# 1369,"inventories",|270
# 1375,"lightning",|698|805|300
# 1380,"landscape change",|655|284
# 1383,"aboveground biomass",|667|716|68|4
# 1392,"actinorhizal plants",|395|433|790
# 1401,"phenolic compounds",|643|666|972
# 1433,"mycorrhizae",|395|218|358
# 1436,"fine root production",|655|656|449|903|904
# 1447,"predation",|655|656|544|444
# 1455,"forest floor",|694|213
# 1466,"organic nitrogen",|643|666|372|394
# 1473,"bulk density",|667|668|77
# 1478,"soil samples",|693|801|989
# 1483,"litterfall",|655|656|305
# 1486,"incubation",|655|656|298|264
# 1492,"abundance",|667|674|6
# 1511,"chronosequences",|693|801|105
# 1513,"water quality",|667|691|623
# 1533,"secchi depth",|667|668|145|490
# 1536,"dunes",|173|798|171
# 1540,"paleoecology",|651|172|399
# 1542,"pollen",|395|433|435
# 1570,"agriculture",|651|17
# 1571,"deserts",|173|798|147
# 1586,"air quality",|667|692|21
# 1590,"air pollution",|643|436|19
# 1592,"ozone",|643|666|397|398
# 1608,"geography",|651|653
# 1609,"processes",None
# 1614,"biology",|651|67
# 1634,"surface elevation table",|693|801|706
# 1635,"land surface properties",|667|673|879
# 1647,"storms",|698|805|556
# 1653,"landsat",|693|705|263|806|282
# 1673,"atmospheric deposition",|655|657|659|49
# 1679,"normalized vegetation index",|667|716|381
# 1690,"buildings",|694|76
# 1693,"grasses",|395|433|951|230
# 1697,"organisms",None
# 1701,"deposition",|655|657|659|144
# 1702,"nitrogen deposition",|655|657|659|144|376
# 1706,"altitude",None
# 1716,"cores",|693|801|129
# 1717,"soil ph",|667|671|410|988
# 1726,"methods",None
# 1741,"larvae",|395|33|271|285
# 1747,"minimum temperature",|667|668|579|342
# 1749,"roads",|694|475
# 1753,"acidic",|667|671|11
# 1755,"imagery",|693|705|263
# 1756,"distance",None
# 1757,"disturbance properties",|667|712
# 1758,"drainage",|655|657|661|167
# 1767,"simulation",|655|664|344|507
# 1768,"nitric acid",|643|666|372|373|369
# 1776,"emissions",|667|205|178
# 1793,"colonization",|655|656|298|113
# 1808,"events",|698
# 1809,"antimony",|643|666|38
# 1810,"cadmium",|643|666|80
# 1811,"chromium",|643|666|104
# 1812,"copper",|643|666|126
# 1831,"dimensions",|667|668|153
# 1861,"nitrogen compounds",|643|666|372|373
# 1868,"physiology",|651|67|420
# 1869,"parasitism",|655|656|544|401
# 1920,"total phosphorus",|643|666|416|592
# 1921,"total nitrogen",|667|671|374|590
# 1933,"satellite imagery",|693|705|263|806
# 1939,"lizards",|395|33|614|466|307
# 1942,"soil disturbance",|655|657|660|522
# 1947,"LiDAR",|693|705|263|807|953
# 1957,"evapotranspiration",|655|657|661|185
# 1958,"transpiration",|655|657|661|185|595
# 1969,"pyranometers",|693|801|977
# 1972,"disturbance patterns",|667|712|165
# 2013,"leaf decomposition",|655|658|137|290
# 2062,"belowground biomass",|667|716|68|61
# 2065,"LiDAR",|693|705|263|807|953
# 2107,"size distribution",|509
# 2113,"marine",|173|41|695|325
# 2116,"organic matter",|643|393
# 2117,"CTD",|667|691|733
# 2118,"primary production",|655|656|449|447
# 2121,"hydrological properties",|667|672
# 2122,"taxonomy",|651|67|578
# 2123,"bacterial abundance",|667|674|6|52
# 2125,"hydrography",|667|673|258
# 2126,"microbes",|395|336
# 2128,"inorganic matter",|643|650
# 2129,"mammals",|395|33|614|320
# 2130,"ocean biogeochemistry",|651|65|385
# 2131,"ecosystem ecology",|651|172|675
# 2132,"scientific activities",|655|664
# 2134,"grazing",|655|239|233
# 2137,"plankton",|395|802
# 2158,"advection",|655|657|659|15
# 2176,"population and community properties",|667|674
# 2179,"biogeochemical processes",|655|658
# 2191,"biodiversity",|651|64
# 2195,"long term",|667|670|311
# 2196,"nitrogen limitation",|667|716|971
# 2197,"nutrient budgets",|667|716|382|1001
# 2198,"nutrient cycles",|667|716|382
# 2200,"primary productivity",None
# 2201,"successional dynamics",|651|172|566
# 2361,"mosses",|395|433|354
# 2502,"fungi",|395|218
# 2769,"roots",|395|433|477
# 2771,"litter",|643|665|302
# 2807,"disturbance",|655|662
# 2870,"forbs",|395|433|951|245|209
# 2904,"crops",|395|433|612|133
# 2905,"ants",|395|33|271|45|267|39
# 2906,"grasslands",|173|798|232
# 2907,"agriculture",|651|17
# 2908,"communities",|799|114
# 2909,"ecosystems",|173
# 2910,"litter",|643|665|302
# 2911,"substrates",None
# 2912,"harvesting",|655|239
# 2913,"microbial biomass",|667|716|68|339
# 2914,"organisms",None
# 2915,"modeling",|655|664|344
# 2916,"acidic",|667|671|11
# 2917,"leaves",|395|433|293
# 2919,"germination",|655|656|298|226
# 2920,"harvesting",|655|239
# 2946,"plant physiology",|651|67|420|430
# 2947,"nitrogen content",|667|671|374
# 2948,"rhizosphere",|694|472
# 2958,"net primary productivity",|667|716|450|364
# 2960,"ecosystem properties",|667|716
# 3004,"dispersal",|655|656|298|156
# 3005,"habitat selection",|655|656|298|237
# 3017,"seed dispersal",|655|656|298|156|495
# 3018,"seed banks",|395|433|612|494
# 3031,"throughfall",|667|672|443|585
# 3041,"time domain reflectometry",|693|801|588
# 3042,"minirhizotrons",|693|801|966
# 3055,"diameter at breast height",|667|917|918
# 3070,"population dynamics",|651|172|438
# 3084,"survivorship",None
# 3093,"microarthropods",|395|33|271|45|335
# 3106,"cellulose",|643|665|95
# 3107,"consumers",|799|208|125
# 3123,"chlorine",|643|666|101
# 3134,"biogeography",|651|653|66
# 3147,"coordinates",|667|673|308|884
# 3158,"nitrogen mineralization",|655|658|383|375|378
# 3175,"tree growth",|655|656|298|236|597
# 3177,"hillslopes",|694|246
# 3247,"nitrogen flux",|667|205|911
# 3251,"root decomposition",|655|658|137|476
# 3299,"sand",|694|484
# 3323,"geology",|651|652
# 3339,"crayfishes",|395|33|271|134|131
# 3451,"human disturbance",|655|662|250
# 3531,"snails",|395|33|271|348|222|512
# 3534,"mollusks",|395|33|271|348
# 3545,"holocene",|667|670|249
# 3605,"inorganic matter",|643|650
# 3663,"periphyton",|395|433|407
# 3694,"marshes",|173|630|326
# 3718,"carbohydrates",|643|666|86|85
# 3727,"mangroves",|173|630|322
# 3753,"total phosphorus",|643|666|416|592
# 3755,"macroalgae",|395|23|316
# 3764,"bulk density",|667|668|77
# 3766,"total nitrogen",|667|671|374|590
# 3771,"soil nutrients",|643|665|384|526
# 3777,"nekton",|395|361
# 3782,"crustaceans",|395|33|271|134
# 3810,"sulfide",|643|666|569|568
# 3825,"seagrass",|395|433|951|230|1003
# 3840,"hammocks",|173|798|938
# 3848,"albedo",|667|668|460|897
# 3859,"physical properties",|667|668
# 3888,"respiration rates",|667|674|468
# 3916,"salinity",|667|671|481
# 3922,"dissolved oxygen",|643|666|397|161
# 4013,"periphyton",|395|433|407
# 4017,"diatoms",|395|23|151
# 4022,"redox",|667|671|459
# 4032,"algae",|395|23
# 4033,"restoration",|655|469
# 4037,"accretion",|655|657|660|7
# 4040,"herbivory",|655|656|544|244
# 4043,"freshwater",|694|216
# 4064,"flux",None
# 4090,"fluorescence",|667|668|202
# 4091,"water",|643|617
# 4092,"dissolved organic carbon",|643|666|86|160
# 4099,"peatland",|173|630|402
# 4112,"eddy covariance",|655|657|659|174
# 4112,"eddy covariance",None
# 4115,"grasshoppers",|395|33|271|45|267|231
# 4150,"inorganic nutrients",|643|665|266
# 4151,"leucine",|643|665|29|296
# 4154,"crabs",|395|33|271|134|130
# 4179,"intertidal",|173|41|941
# 4181,"mud",|694|535|356
# 4218,"epifauna",|395|882|942
# 4219,"infauna",|395|882|943
# 4246,"ascomycetes",|395|218|46
# 4288,"slugs",|395|33|271|348|222|510
# 4299,"tides",|698|586
# 4303,"cesium",|643|666|97
# 4367,"polychaetes",|395|33|271|42|894
# 4393,"holocene",|667|670|249
# 4406,"salt marshes",|173|630|326|482
# 4448,"speciation",|655|656|186|540
# 4501,"morphology",None
# 4663,"evolution",|655|656|186
# 4690,"acid neutralizing capacity",|667|671|9
# 4691,"fluorine",|643|666|204
# 4726,"plant biomass",|667|716|68|423
# 4733,"fluoride",|643|666|204|203
# 4739,"frost",|698|217
# 4740,"snow water equivalence",|694|513|803
# 4913,"belowground production",|655|656|449|903
# 4940,"soil horizons",|694|535|523
# 4992,"digital elevation model",|693|705|152
# 4995,"altitude",None
# 4998,"hurricane damage",|667|712|255
# 5005,"acid rain",|643|436|10
# 5009,"extinction",|655|656|186|188
# 5010,"life history",|655|656|298
# 5013,"paleolimnology",|651|301|400
# 5015,"hurricanes",|698|805|254
# 5016,"defoliation",|655|239|138
# 5018,"geological processes",|655|657|660
# 5019,"fens",|173|630|926
# 5020,"dendrometers",|693|801|141
# 5022,"ferns",|395|433|951|190
# 5023,"hyporheic zone",|694|261
# 5024,"carbon monoxide",|643|666|86|91
# 5025,"sulfur hexafluoride",|643|666|204|203|570
# 5026,"analytical tools",|693|808
# 5027,"vegetation dynamics",|651|172|427|613
# 5034,"plant functional types",|693|705|973
# 5059,"termites",|395|33|271|45|267|580
# 5068,"hydrology",|651|259
# 5110,"playa",|173|798|147|434
# 5123,"rabbits",|395|33|614|320|511|453
# 5168,"elements and compounds",|643|666
# 5205,"annual net primary production",|667|716|450|364|36
# 5240,"atmospheric processes",|655|657|659
# 5245,"atmospheric properties",|667|692
# 5248,"desertification",|655|284|146
# 5288,"mites",|395|33|271|45|267|343
# 5317,"biological events",|698|710
# 5344,"revegetation",|655|284|471
# 5372,"soil microarthropods",|395|33|271|45|335|524
# 5571,"hydrologic processes",|655|657|661
# 5573,"herbivores",|799|208|125|243
# 5580,"abundance",|667|674|6
# 5582,"rain",|667|672|443|455
# 5583,"consumers",|799|208|125
# 5663,"irrigation",|655|657|661|275
# 5664,"soil water content",|667|672|621|534
# 5672,"mowing",|655|239|355
# 5673,"spores",|395|218|550
# 5680,"plants",|395|433
# 5684,"diversity",|667|674|166
# 5685,"reproduction",|655|656|298|465
# 5705,"atmospheric processes",|655|657|659
# 5709,"interception",|667|672|443|268
# 5714,"standing crop",|667|674|554
# 5736,"physiological processes",|655|800
# 5744,"disciplines",|651
# 5745,"adaptation",|655|656|186|14
# 5746,"biological processes",|655|656
# 5747,"organizational units",|799
# 5748,"substances",|643
# 5749,"electric exclusion",|655|664|175
# 5759,"community dynamics",|651|172|116
# 5764,"biological substances",|643|665
# 5778,"basidiomycetes",|395|218|57
# 5780,"methods",None
# 5789,"animals",|395|33
# 5791,"basidiomycetes",|395|218|57
# 5804,"field methods",|693|801
# 5805,"wet deposition",|655|657|659|144|629
# 5807,"physiological processes",|655|800
# 5809,"leaf litter",|395|433|612|291
# 5855,"macroinvertebrates",|395|33|271|318
# 5926,"mass balance",|655|664|328
# 5927,"thickness",|667|668|153|583
# 5991,"lake level",|667|672|622|277
# 6007,"dispersion",|655|657|157
# 6013,"community respiration",|655|685
# 6033,"hydrogen ions",|643|272|93|257
# 6044,"snow temperature",|667|668|579|516
# 6060,"hyporheic",|667|673|260
# 6082,"marine",|173|41|695|325
# 6085,"fishes",|395|33|614|196
# 6086,"species richness",|651|64|546
# 6098,"alkalinity",|667|671|24
# 6101,"oceanography",|651|700
# 6103,"bacteria",|395|336|51
# 6105,"coral reefs",|173|41|960|127
# 6121,"ocean acidification",|655|657|962
# 6131,"symbiosis",|655|656|544|575
# 6132,"coral reefs",|173|41|960|127
# 6141,"water temperature",|667|668|579|625
# 6142,"bathymetry",|667|673|59
# 6144,"coral reefs",|173|41|960|127
# 6154,"corals",|395|33|271|128
# 6164,"corals",|395|33|271|128
# 6176,"trophic dynamics",|651|172|602
# 6189,"sediments",|643|493
# 6192,"accumulation",|655|8
# 6193,"particulate organic carbon",|643|666|86|390|892
# 6219,"zooplankton",|395|802|641
# 6225,"recruitment",|698|710|458
# 6230,"solar radiation",|667|668|454|536
# 6245,"depth",|667|668|145
# 6246,"dimensions",|667|668|153
# 6248,"physical properties",|667|668
# 6251,"photosynthesis",|655|800|417
# 6258,"demography",|651|682
# 6259,"growth",|655|656|298|236
# 6261,"predation",|655|656|544|444
# 6262,"surveys",|693|571
# 6264,"reefs",|173|41|960
# 6265,"respiration rates",|667|674|468
# 6267,"physiology",|651|67|420
# 6273,"species composition",|667|674|166|542
# 6275,"conductivity",|667|668|176|122
# 6276,"scattering",|655|657|487
# 6277,"density",|667|668|916
# 6278,"ocean currents",|655|657|386
# 6279,"pressure",None
# 6290,"light",|667|668|454|299
# 6299,"chlorophyll",|643|665|102
# 6302,"ocean color",|667|691|890
# 6310,"water column",|694|620
# 6316,"community composition",|667|674|115
# 6319,"ocean acidification",|655|657|962
# 6344,"allometry",|667|716|25
# 6345,"macroalgae",|395|23|316
# 6353,"habitats",|799|238
# 6374,"oceans",|173|41|695
# 6375,"community structure",|799|114|119
# 6389,"wind speed",|667|692|633|635
# 6390,"air temperature",|667|668|579|22
# 6392,"atmospheric pressure",|667|692|50
# 6395,"meteorology",|651|333
# 6397,"relative humidity",|667|692|611|253|463
# 6398,"weather",|667|692|627
# 6399,"wind direction",|667|692|633|634
# 6409,"chlorophyll",|643|665|102
# 6419,"inorganic matter",|643|650
# 6420,"stable isotopes",|643|276|551
# 6421,"carbon to nitrogen ratio",|667|671|92
# 6423,"phytoplankton",|395|802|421
# 6424,"grazing",|655|239|233
# 6425,"population dynamics",|651|172|438
# 6426,"trophic dynamics",|651|172|602
# 6464,"boron",|643|666|71
# 6465,"nickel",|643|666|367
# 6567,"land use",|667|673|280
# 6576,"census",|693|571|96
# 6680,"limnology",|651|301
# 6698,"rivers",|173|41|474
# 6719,"invasive species",|799|541|269
# 6728,"benthos",|395|882
# 6732,"invasive species",|799|541|269
# 6736,"aquatic ecosystems",|173|41
# 6741,"metabolism",|655|800|332
# 6742,"oxygen",|643|666|397
# 6834,"alpine",|173|798|26
# 7058,"discharge",|655|657|661|154
# 7111,"snow depth",|667|668|145|515
# 7112,"water content",|667|672|621
# 7116,"montane",|173|798|350
# 7120,"bulk deposition",|655|657|659|144|78
# 7121,"dry deposition",|655|657|659|144|169
# 7172,"elevation",|667|673|879|177
# 7312,"hydrography",|667|673|258
# 7432,"landsat",|693|705|263|806|282
# 7440,"topography",|667|673|589
# 7447,"digital elevation model",|693|705|152
# 7452,"mapping",|655|664|323
# 7563,"macrofauna",|395|33|189|317
# 7606,"polychaetes",|395|33|271|42|894
# 7641,"stream order",|667|672|560
# 7645,"watersheds",|173|798|626
# 7707,"land use",|667|673|280
# 7730,"dew point",|667|692|150
# 7734,"atmospheric pressure",|667|692|50
# 7735,"dew point",|667|692|150
# 7744,"nitrate",|643|666|372|373|368
# 7745,"organic carbon",|643|666|86|390
# 7746,"phosphate",|643|666|416|415
# 7750,"radiation",|667|668|454
# 7751,"ammonia",|643|666|372|373|30
# 7752,"nitrite",|643|666|372|373|371
# 7753,"photosynthetically active radiation",|667|668|454|418
# 7771,"kelp",|395|433|958
# 7773,"genomics",|651|67|907
# 7773,"genomics",|651|957
# 7779,"nitrogen-15",|643|666|372|379
# 7796,"humidity",|667|692|611|253
# 7799,"solar radiation",|667|668|454|536
# 7814,"beaches",|173|798|955
# 7818,"advection",|655|657|659|15
# 7832,"species",|799|541
# 7843,"irradiance",|667|668|274
# 7874,"ammonium",|643|666|372|373|31
# 7952,"stage height",|667|672|622|553
# 7979,"gross primary production",|655|656|449|447|905
# 7982,"net primary production",|655|656|449|447|363
# 8038,"species diversity",|651|64|543
# 8066,"predators",|799|208|445
# 8101,"crabs",|395|33|271|134|130
# 8103,"gastropods",|395|33|271|348|222
# 8135,"nitrogen compounds",|643|666|372|373
# 8137,"suspended solids",|667|691|623|574
# 8144,"endangered species",|799|541|179
# 8215,"droughts",|698|805|168
# 8217,"grasslands",|173|798|232
# 8218,"plant growth",|655|656|449|428
# 8223,"plant phenology",|651|67|413|429
# 8225,"plant physiology",|651|67|420|430
# 8276,"morphometrics",|651|968
# 8284,"climate change",|651|333|111|110
# 8291,"microbial biomass",|667|716|68|339
# 8401,"cesium",|643|666|97
# 8406,"landscape change",|655|284
# 8433,"beaches",|173|798|955
# 8438,"water quality",|667|691|623
# 8463,"barrier islands",|173|798|898
# 8517,"tree age",|667|917|996
# 8560,"erosion",|655|657|660|181
# 8571,"dispersal",|655|656|298|156
# 8580,"pleistocene",|667|670|934
# 8598,"standing crop",|667|674|554
# done
