# %% [markdown]
# # Fetchs Data Packages, Keywords and Thesaurus info
# This Notebook uses web services to download the packageid,title and list of keywords for each LTER dataset in EDI (based on the knb-lter-* scope) and queries the LTER Thesaurus using Tematres web services to gather information on which keywords are found in the thesaurus, and if so, which high-level category it falls into. Several intermediate CSV files are created along the way and contain the information needed to produce a spreadsheet listing the keywording data using a separate R program.  -John Porter, 2022

# %% [markdown]
# ### Fetch keyword data from PASTA

# %%
import requests

r=requests.get('https://pasta.lternet.edu/package/search/eml?defType=edismax&q=*&fq=-scope:ecotrends&fq=-scope:knb-lter-landsat*&fq=scope:edi*&fl=packageid,title,keyword&sort=score,desc&sort=packageid,asc&debug=false&rows=1000000',verify=False)
f=open("resultSetEDI.xml","w",encoding='utf-8')
f.write(r.text)
f.close()
print("Done")
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pasta.lternet.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Done

# %% [markdown]
# ### Parse ResultSet XML and create a csv file to read in as a Pandas data frame

# %%
import xml.etree.ElementTree as Xet
import numpy as np
import pandas as pd 

# create an output file and write the header
f=open("resultSetKeywordsEDI.csv","w",encoding="utf=8")
f.write("packageid,title,keyword\n")
# now parse the XML and write it out
resultSetxmlparse=Xet.parse("resultSetEDI.xml")
root=resultSetxmlparse.getroot()

for i in root:
    packageid=i.find("packageid").text
    title=i.find("title").text
    title=title.replace('\r','').replace('\n','') # get rid of embedded linefeeds in titles
    for k in i.iter("keyword"):
        keyword=str(k.text)
        f.write(packageid+',"'+title+'","'+keyword+'"\n')
f.close()  
resultSetDataFrame =pd.read_csv("resultSetKeywordsEDI.csv" 
          ,skiprows=1
            ,sep=","  
                ,quotechar='"' 
           , names=[
                    "pakcageid",     
                    "title",     
                    "keyword"]
                               )
print(resultSetDataFrame.info())
print("Done")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13078 entries, 0 to 13077
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pakcageid  13078 non-null  object
#  1   title      13078 non-null  object
#  2   keyword    13078 non-null  object
# dtypes: object(3)
# memory usage: 306.6+ KB
# None
# Done

# %% [markdown]
# ### Get list of top-level LTER Vocab units

# %%
topr=requests.get('https://vocab.lternet.edu/vocab/vocab/services.php?task=fetchTopTerms',verify=False)
f=open("TopLevelTerms.xml","w",encoding='utf-8')
f.write(topr.text)
f.close()
print("Done")
# Out:
# Done
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'vocab.lternet.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### and create  lists of their names and term_ids

# %%
topTermsxmlparse=Xet.parse("TopLevelTerms.xml")
rootTop=topTermsxmlparse.getroot()
topCounter=0

term_id=list()
term_string=list()
for i in rootTop.iter('term_id'):
    term_id.append(i.text)
for i in rootTop.iter('string'):
    term_string.append(i.text)
    topCounter=topCounter+1
print(term_id)
print(term_string)

f=open("TopLevelTerms.csv","w",encoding="utf-8")
for i in range(len(term_id)):
    f.write(term_string[i]+","+str(term_id[i])+"\n")
f.close()
# Out:
# ['799', '651', '698', '667', '693', '655', '643', '694', '173', '395']
# ['organizational units', 'disciplines', 'events', 'measurements', 'methods', 'processes', 'substances', 'substrates', 'ecosystems', 'organisms']

# %% [markdown]
# ### Run Queries of keywords against Tematres web services to see if they match and what the top of the hierarchy is

# %%
import warnings

# create a list of keywords without duplicates
kwList=[]
[kwList.append(x) for x in resultSetDataFrame.keyword if x not in kwList]
print(len(kwList))
print(kwList)
# Out:
# 3930
# ['LTREB', 'NSF', 'plant community', 'succession', 'fertilization', 'Macrosystems Biology', 'MSB', 'Cross-scale Interactions', 'CSI', 'National Science Foundation', 'lakes', 'multi-scaled', 'geospatial', 'geography', 'temporal', 'database', 'LAGOS', 'LAGOS-NE', 'nutrients', 'dissolved nutrients', 'inorganic nutrients', 'water quality', 'water properties', 'water clarity', 'chlorophyll', 'ecological context', 'lake trophic state', 'eutrophication', 'support package', 'semantic web', 'annotations', 'functional diversity', 'functional traits', 'Orinoquia', 'Morphometric traits', 'life-history traits', 'Darwin Core Archive (DwC-A) Event Core', 'GBIF', 'Global Biodiversity Information Facility', 'Taxon: ScientificName', 'ExtendedMeasurementOrFact', 'Event', 'Occurrence', 'Population Abundance', 'Disturbance Patterns', 'populations', 'abundance', 'aquatic invertebrates', 'biomass', 'gastropods', 'invertebrates', 'long term', 'long term ecological research', 'LTER', 'macroinvertebrates', 'marine', 'measurements', 'mollusks', 'organism', 'Santa Barbara Coastal', 'species', 'transects', 'Community Structure', 'Kelp Forest', 'Reef', 'Arroyo Quemado Reef', 'Carpinteria Reef', 'Mohawk Reef', 'Naples Reef', 'Cover', 'Estimation', 'Live Weight', 'Reefs', 'Species', 'core', 'crustaceans', 'ongoing', 'communities', 'community composition', 'community dynamics', 'community patterns', 'species composition', 'species diversity', 'species richness', 'basisOfRecord: HumanObservation', 'Nitrous Oxide', 'Carbon Dioxide', 'N2O', 'CO2', 'Greenhouse Gas', 'Iowa', 'Central Iowa', 'Agriculture', 'Corn', 'Zea mays', 'Soy', 'Glycine max', 'Soil', 'Nitrogen', 'Soil Carbon', 'Soil Moisture', 'Prairie Pothole', 'Trace Gas Emissions', 'Denitrification', 'Soil Drainage', 'Upper Clark Fork River restoration', 'NSF DEB LTREB 1655197', 'Montana', 'Northwestern United States', 'Northwestern Forested Mountains Ecoregion', 'river water', 'dissolved organic carbon', 'Plant communities', 'Plant species', 'Plant biomass', 'surveys suspended sediment', 'Limnology', 'coastal', 'aquatic plants', 'submerged aquatic vegetation', 'Michigan Tech', 'Population and community properties', 'total nitrogen', 'total phosphorus', 'ammonium', 'nitrate', 'chlorophyll a', 'soluble reactive phosphorus', 'chemical properties', 'water column', 'light', 'algae', 'seston', 'vascular plants', 'spatial raster', 'Enhanced Forest Inventory', 'ALS', 'Forest Biomass', 'New England', 'Forest Ecology', 'Forest Map', 'LiDAR', 'phosphorus', 'sediments', 'spatial variability', 'seasonality', 'ecosystems', 'limnology', 'biogeochemistry', 'nutrient cycling', 'water temperature', 'soil carbon', 'soil chemistry', 'soil horizons', 'soil organic matter', 'radiocarbon', 'density fraction', 'calcium carbonate', ' oxyhydroxides', 'Clear Creek', 'Gravel augementation', 'Spawning habitat', 'Salmon habitat restoration', 'CVPIA', 'streams', 'water chemistry', 'aquatic ecosystems', 'tropical', 'temperate', 'Nutrients', 'Great Lakes', 'Lake Michigan', 'salinization', 'loading', 'synoptic sampling', 'chemical limnology', 'chloride', 'river', 'creek', 'land use', 'Arbuscular mycorrhizal fungi', 'urbanization', 'Great Smoky Mountains National Park', 'fire', 'Ponds', 'Pond', 'literature survey', 'waterbody size', 'ecosystem function', 'definitions', 'freshwater', 'wetlands', 'Mpala Research Centre', 'Ol Pejeta Conservancy', 'parasite', 'water sources', 'aridity', 'aggregation', 'Kenya', 'watering hole', 'cattle', 'elephant', 'zebra', 'impala', 'giraffe', 'buffalo', 'herbivore', 'rainfall', 'reservoirs', 'dams', 'conterminous US', 'classification', 'ResNet18', 'Salinization', '18S rRNA metabarcoding', 'Freshwater', 'Eukaryote community', 'Chloride', 'Plankton', 'flume', 'extracellular polymeric substances', 'aggregate stability', 'soil erodibility', 'acoustic doppler profiler', 'litter', 'competition', 'invasive species', 'disease', 'SRS Corridor', 'connectivity', 'corridors', 'edge effects', 'fragment shape', 'habitat fra ...

# %%
f=open("termHierarchiesEDI.csv","w",encoding='utf-8',buffering=1)
counter=0
startCounter=0  # use for restarts. Be sure to rename old file before it is overwritten
for kw in kwList:
    #print(kw)
    counter=counter+1
    if (counter >= startCounter):
        warnings.filterwarnings("ignore") # eliminate security warning about verify option
        termr=requests.get('https://vocab.lternet.edu/vocab/vocab/services.php?task=search&arg='+str(kw),verify=False)
        warnings.filterwarnings("default")
        kwRoot=Xet.fromstring(termr.text)
        for i in kwRoot.iter("term"):
            if (i.find("string") is not None):
                termString=str(i.find("string").text )
                indexString=str(i.find("index").text )
                if (kw.lower() == termString.lower()):
                    print(str(counter)+',"'+termString+'",'+indexString)
                    f.write('"'+ kw +'",'+indexString+'\n')
f.close()
print("done")
# Out:
# 4,"succession",|655|656|686
# 5,"fertilization",|655|191
# 11,"lakes",|173|41|278
# 14,"geography",|651|653
# 19,"nutrients",|643|665|384
# 20,"dissolved nutrients",|643|665|384|159
# 21,"inorganic nutrients",|643|665|266
# 22,"water quality",|667|691|623
# 23,"water properties",|667|691
# 25,"chlorophyll",|643|665|102
# 45,"disturbance patterns",|667|712|165
# 46,"populations",|799|439
# 47,"abundance",|667|674|6
# 48,"aquatic invertebrates",|395|33|271|42
# 49,"biomass",|667|716|68
# 50,"gastropods",|395|33|271|348|222
# 51,"invertebrates",|395|33|271
# 52,"long term",|667|670|311
# 55,"macroinvertebrates",|395|33|271|318
# 56,"marine",|173|41|695|325
# 57,"measurements",None
# 58,"mollusks",|395|33|271|348
# 61,"species",|799|541
# 62,"transects",|693|801|594
# 63,"community structure",|799|114|119
# 73,"reefs",|173|41|960
# 74,"species",|799|541
# 76,"crustaceans",|395|33|271|134
# 78,"communities",|799|114
# 79,"community composition",|667|674|115
# 80,"community dynamics",|651|172|116
# 81,"community patterns",|799|114|117
# 82,"species composition",|667|674|166|542
# 83,"species diversity",|651|64|543
# 84,"species richness",|651|64|546
# 86,"nitrous oxide",|643|666|372|373|380
# 87,"carbon dioxide",|643|666|86|89
# 93,"agriculture",|651|17
# 98,"soil",|694|535
# 99,"nitrogen",|643|666|372
# 100,"soil carbon",|643|666|86|520
# 101,"soil moisture",|643|617|525
# 104,"denitrification",|655|658|383|375|142
# 112,"dissolved organic carbon",|643|666|86|160
# 113,"plant communities",|799|114|424
# 114,"plant species",|799|541|431
# 115,"plant biomass",|667|716|68|423
# 117,"limnology",|651|301
# 122,"population and community properties",|667|674
# 123,"total nitrogen",|667|671|374|590
# 124,"total phosphorus",|643|666|416|592
# 125,"ammonium",|643|666|372|373|31
# 126,"nitrate",|643|666|372|373|368
# 127,"chlorophyll a",|643|665|103
# 128,"soluble reactive phosphorus",|643|666|416|537
# 129,"chemical properties",|667|671
# 130,"water column",|694|620
# 131,"light",|667|668|454|299
# 132,"algae",|395|23
# 133,"seston",|395|500
# 134,"vascular plants",|395|433|951
# 140,"forest ecology",|651|172|211
# 142,"LiDAR",|693|705|263|807|953
# 143,"phosphorus",|643|666|416
# 144,"sediments",|643|493
# 145,"spatial variability",|667|673|539
# 146,"seasonality",|667|670|489
# 147,"ecosystems",|173
# 148,"limnology",|651|301
# 149,"biogeochemistry",|651|65
# 150,"nutrient cycling",|655|658|383
# 151,"water temperature",|667|668|579|625
# 152,"soil carbon",|643|666|86|520
# 153,"soil chemistry",|651|99|521
# 154,"soil horizons",|694|535|523
# 155,"soil organic matter",|643|393|527
# 165,"streams",|173|41|562
# 166,"water chemistry",|651|99|619
# 167,"aquatic ecosystems",|173|41
# 170,"nutrients",|643|665|384
# 177,"chloride",|643|666|101|100
# 180,"land use",|667|673|280
# 185,"ponds",|173|41|975
# 191,"freshwater",|694|216
# 192,"wetlands",|173|630
# 216,"freshwater",|694|216
# 218,"chloride",|643|666|101|100
# 219,"plankton",|395|802
# 225,"litter",|643|665|302
# 226,"competition",|655|656|544|120
# 227,"invasive species",|799|541|269
# 228,"disease",|655|656|155
# 235,"herbivory",|655|656|544|244
# 236,"plant growth",|655|656|449|428
# 240,"nitrogen",|643|666|372
# 241,"winter",|667|670|636
# 242,"birds",|395|33|614|69
# 243,"buildings",|694|76
# 244,"land cover",|667|673|279
# 245,"landscape",None
# 246,"forests",|173|798|212|2
# 247,"biodiversity",|651|64
# 261,"coral reefs",|173|41|960|127
# 268,"dissolved oxygen",|643|666|397|161
# 270,"ph",|667|671|410
# 275,"water temperature",|667|668|579|625
# 276,"wind speed",|667|692|633|635
# 277,"methane",|643|666|86|334
# 278,"carbon dioxide",|643|666|86|89
# 279,"flux",None
# 280,"vegetation",|395|433|612
# 281,"water",|643|617
# 292,"reproduction",|655|656|298|465
# 293,"flowers",|395|433|200
# 294,"flowering",|698|710|199
# 307,"trophic structure",|667|674|603
# 309,"life history",|655|656|298
# 323,"microbes",|395|336
# 324,"plants",|395|433
# 325,"viruses",|395|336|615
# 326,"species interactions",|655|656|544
# 327,"dissolved oxygen",|643|666|397|161
# 328,"ph",|667|671|410
# 329,"alpine",|173|798|26
# 330,"altitude",None
# 331,"pressure",None
# 332,"turbidity",|667|691|606
# 333,"depth",|667|668|145
# 340,"montane",|173|798|350
# 346,"benthos",|395|882
# 347,"animals",|395|33
# 348,"arthropods",|395|33|271|45
# 349,"diversity",|667|674|166
# 350,"ecology",|651|172
# 351,"estuaries",|173|41|182
# 352,"epifauna",|395|882|942
# 353,"infauna",|395|882|943
# 354,"monitoring",|655|664|349
# 355,"polychaetes",|395|33|271|42|894
# 356,"rivers",|173|41|474
# 357,"snails",|395|33|271|348|222|512
# 358,"species abundance",|667|674|6|990
# 359,"surveys",|693|571
# 373,"aboveground biomass",|667|716|68|4
# 374,"climate change",|651|333|111|110
# 377,"plant species",|799|541|431
# 383,"organic matter",|643|393
# 384,"incubation",|655|656|298|264
# 388,"disturbance patterns",|667|712|165
# 389,"canopy cover",|667|716|83
# 390,"plant cover",|667|716|426
# 391,"basal area",|667|917|56
# 392,"plant biomass",|667|716|68|423
# 393,"stems",|395|433|612|555
# 394,"aboveground biomass",|667|716|68|4
# 395,"habitats",|799|238
# 396,"plant communities",|799|114|424
# 397,"stand structure",|799|114|119|991
# 398,"species lists",|799|541|545
# 399,"plant species composition",|651|64|432
# 400,"biology",|651|67
# 401,"forest ecology",|651|172|211
# 402,"forest ecosystems",|173|798|212
# 403,"ecosystem ecology",|651|172|675
# 404,"forest dynamics",|651|172|427|931
# 405,"vegetation dynamics",|651|172|427|613
# 406,"successional dynamics",|651|172|566
# 407,"conservation",|651|124
# 408,"permanent plots",|693|801|409
# 409,"census",|693|571|96
# 410,"recovery",|655|457
# 411,"restoration",|655|469
# 412,"forest disturbance",|655|662|210
# 413,"disturbances",|698|805
# 414,"fires",|698|805|195
# 415,"landscape change",|655|284
# 416,"wood",|643|665|637
# 417,"coarse woody debris",|643|665|638|112
# 418,"woody debris",|643|665|638
# 419,"lichens",|395|297
# 420,"seedlings",|395|433|498
# 421,"treeline",|395|433|612|600
# 422,"understory vegetation",|395|433|612|607
# 423,"insects",|395|33|271|45|267
# 424,"trees",|395|433|951|1
# 425,"herbs",|395|433|951|245
# 426,"grasses",|395|433|951|230
# 427,"ferns",|395|433|951|190
# 428,"shrubs",|395|433|951|503
# 431,"denitrification",|655|658|383|375|142
# 432,"urban",|667|673|609
# 433,"nitrogen cycling",|655|658|383|375
# 434,"bulk density",|667|668|77
# 435,"porosity",|667|668|441
# 436,"microclimate",|667|692|109|340
# 452,"temperature",|667|668|579
# 453,"irradiance",|667|668|274
# 455,"specific conductivity",|667|668|176|122|548
# 457,"soil samples",|693|801|989
# 458,"carbon",|643|666|86
# 459,"climate change",|651|333|111|110
# 480,"dispersal",|655|656|298|156
# 481,"colonization",|655|656|298|113
# 486,"habitat selection",|655|656|298|237
# 496,"dissolved organic carbon",|643|666|86|160
# 504,"food webs",|799|208
# 507,"long term monitoring",|655|664|349|313
# 508,"nitrous oxide",|643|666|372|373|380
# 509,"watersheds",|173|798|626
# 510,"disturbance",|655|662
# 516,"water quality",|667|691|623
# 517,"stream ecology",|651|172|559
# 518,"hydrology",|651|259
# 529,"atmospheric properties",|667|692
# 530,"air quality",|667|692|21
# 531,"climate",|667|692|109
# 532,"precipitation",|667|672|443
# 533,"weather",|667|692|627
# 534,"wind",|667|692|633
# 542,"gas flux",|667|205|220
# 543,"heat flux",|667|205|241
# 544,"eddy covariance",|655|657|659|174
# 544,"eddy covariance",None
# 546,"meteorology",|651|333
# 547,"gases",|643|221
# 548,"geomorphology",|651|652|225
# 561,"silviculture",|651|17|506
# 562,"thinning",|655|239|584
# 563,"seed production",|655|656|449|986
# 564,"dendrochronology",|651|67|140
# 587,"throughfall",|667|672|443|585
# 588,"stream ecology",|651|172|559
# 596,"conductivity",|667|668|176|122
# 598,"physical properties",|667|668
# 599,"fluorescence",|667|668|202
# 609,"climate",|667|692|109
# 610,"oceanography",|651|700
# 620,"succession",|655|656|686
# 622,"phytoplankton",|395|802|421
# 626,"carbon",|643|666|86
# 627,"carbon to nitrogen ratio",|667|671|92
# 630,"fishes",|395|33|614|196
# 631,"endangered species",|799|541|179
# 637,"biogeochemical processes",|655|658
# 638,"redox",|667|671|459
# 639,"salinity",|667|671|481
# 643,"sodium",|643|666|518
# 659,"carbon flux",|667|205|90
# 661,"carbon cycling",|655|656|88
# 662,"copper",|643|666|126
# 663,"grazing",|655|239|233
# 664,"rotifers",|395|336|452|478
# 665,"protozoa",|395|336|452
# 666,"nitrite",|643|666|372|373|371
# 667,"ammonia",|643|666|372|373|30
# 678,"phosphate",|643|666|416|415
# 696,"precipitation",|667|672|443
# 705,"weather",|667|692|627
# 706,"solar radiation",|667|668|454|536
# 710,"larvae",|395|33|271|285
# 712,"temperature",|667|668|579
# 713,"dissolved oxygen",|643|666|397|161
# 715,"respiration",|655|656|88|467
# 716,"gross primary production",|655|656|449|447|905
# 719,"light",|667|668|454|299
# 736,"corals",|395|33|271|128
# 737,"populations",|799|439
# 739,"coral reefs",|173|41|960|127
# 744,"ocean acidification",|655|657|962
# 750,"wind speed",|667|692|633|635
# 751,"wind direction",|667|692|633|634
# 752,"maximum temperature",|667|668|579|329
# 753,"minimum temperature",|667|668|579|342
# 754,"wind",|667|692|633
# 755,"fertilizer",|643|192
# 756,"soil",|694|535
# 757,"lysimeters",|693|801|315
# 758,"soil moisture",|643|617|525
# 759,"crops",|395|433|612|133
# 760,"soil phosphorus",|643|666|416|987
# 761,"soil samples",|693|801|989
# 762,"soil ph",|667|671|410|988
# 763,"potassium",|643|666|442
# 764,"relative humidity",|667|692|611|253|463
# 765,"soil temperature",|667|668|579|530
# 775,"regeneration",|655|656|298|461
# 787,"zooplankton",|395|802|641
# 788,"nitrogen fixation",|655|658|383|375|377
# 790,"air temperature",|667|668|579|22
# 792,"photosynthetically active radiation",|667|668|454|418
# 796,"albedo",|667|668|460|897
# 801,"phosphorus",|643|666|416
# 808,"dissolved inorganic carbon",|643|666|86|158
